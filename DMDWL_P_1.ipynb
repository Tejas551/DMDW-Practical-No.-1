# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#read data from dataset into dataframe
df=pd.read_csv('Data for repository.csv')

# %%
#display first 4 rows
df.head()
# Out:
#          Movie Name Release Period Whether Remake Whether Franchise     Genre  \
# 0       Golden Boys         Normal             No                No  suspense
# 1     Kaccha Limboo        Holiday             No                No     drama
# 2  Not A Love Story        Holiday             No                No  thriller
# 3        Qaidi Band        Holiday             No                No     drama
# 4         Chaatwali        Holiday             No                No     adult
#
#   New Actor New Director New Music Director         Lead Star  \
# 0       Yes           No                 No      Jeet Goswami
# 1       Yes           No                Yes  Karan Bhanushali
# 2        No           No                 No        Mahie Gill
# 3       Yes           No                 No        Aadar Jain
# 4       Yes          Yes                Yes        Aadil Khan
#
#           Director   Music Director  Number of Screens  Revenue(INR)  \
# ...

# %%
# get information about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Movie Name          1698 non-null   object
#  1   Release Period      1698 non-null   object
#  2   Whether Remake      1698 non-null   object
#  3   Whether Franchise   1698 non-null   object
#  4   Genre               1698 non-null   object
#  5   New Actor           1698 non-null   object
#  6   New Director        1698 non-null   object
#  7   New Music Director  1698 non-null   object
#  8   Lead Star           1698 non-null   object
#  9   Director            1698 non-null   object
#  10  Music Director      1698 non-null   object
#  11  Number of Screens   1698 non-null   int64
#  12  Revenue(INR)        1698 non-null   int64
#  13  Budget(INR)         1698 non-null   int64
# dtypes: int64(3), object(11)
# memory usage: 185.8+ KB

# %%
# 1.Data Reduction
#Remove/reduce unnecessary arribute from dataframe
subset = df[['Movie Name','Release Period','Genre','Lead Star','Director']]
subset.head()
# Out:
#          Movie Name Release Period     Genre         Lead Star  \
# 0       Golden Boys         Normal  suspense      Jeet Goswami
# 1     Kaccha Limboo        Holiday     drama  Karan Bhanushali
# 2  Not A Love Story        Holiday  thriller        Mahie Gill
# 3        Qaidi Band        Holiday     drama        Aadar Jain
# 4         Chaatwali        Holiday     adult        Aadil Khan
#
#           Director
# 0       Ravi Varma
# 1    Sagar Ballary
# 2  Ram Gopal Verma
# 3     Habib Faisal
# 4       Aadil Khan

# %%
# 2.Data Cleaning
#find missing values
subset.isnull().sum()
# Out:
# Movie Name        0
# Release Period    0
# Genre             0
# Lead Star         0
# Director          0
# dtype: int64

# %%
#define  function for median
def impute_median(series):
  return series.filla(series.median())

# %%
subset2=df[['Movie Name','Number of Screens','Budget(INR)','Revenue(INR)']]
subset2.head()
# Out:
#          Movie Name  Number of Screens  Budget(INR)  Revenue(INR)
# 0       Golden Boys                  5        85000       5000000
# 1     Kaccha Limboo                 75       825000      15000000
# 2  Not A Love Story                525     56700000      75000000
# 3        Qaidi Band                800      4500000     210000000
# 4         Chaatwali                  1      1075000       1000000

# %%
# 3.Data integration
subset3=pd.merge(subset,subset2,on='Movie Name')
subset3.head()
# Out:
#          Movie Name Release Period     Genre         Lead Star  \
# 0       Golden Boys         Normal  suspense      Jeet Goswami
# 1     Kaccha Limboo        Holiday     drama  Karan Bhanushali
# 2  Not A Love Story        Holiday  thriller        Mahie Gill
# 3        Qaidi Band        Holiday     drama        Aadar Jain
# 4         Chaatwali        Holiday     adult        Aadil Khan
#
#           Director  Number of Screens  Budget(INR)  Revenue(INR)
# 0       Ravi Varma                  5        85000       5000000
# 1    Sagar Ballary                 75       825000      15000000
# 2  Ram Gopal Verma                525     56700000      75000000
# 3     Habib Faisal                800      4500000     210000000
# 4       Aadil Khan                  1      1075000       1000000

# %%
# 4.Data Transformation
subset3.to_excel('Data for repository.xlsx')
